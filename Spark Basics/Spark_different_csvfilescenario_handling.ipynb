# %%
df= spark.read.csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales.csv")
df.show()

# %%
df = spark.read.format("csv").load("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales.csv")

df.display()

# %%
df= spark.read.csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales.csv" , header='True',inferSchema='True')

df.display()

# %%
df = spark.read.csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_no_header.csv").display()

# %%
schmea_str = "id int, customer_name string, product string, quantity int, price int, Comments string"
df = spark.read.schema(schmea_str).csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_no_header.csv")
df.display()

# %%
from pyspark.sql.types import StructType,StructField,IntegerType,StringType
schema = StructType([
    StructField("id",IntegerType(),True),
    StructField("customer_name",StringType(),True),
    StructField("product",StringType(),True),
    StructField("quantity",IntegerType(),True),
    StructField("price",IntegerType(),True),
    StructField("Comments",StringType(),True)
])
df = spark.read.schema(schema).csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_no_header.csv")
df.display()

# %%
df= spark.read.csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_pipe.csv",header='True',inferSchema='True')
df.display()

# %%
df = spark.read.csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_pipe.csv",header='True',sep='|',inferSchema='True')
df.display()

# %%
df = spark.read.option("delimiter","|").csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_pipe_single_quote.csv",header='True',inferSchema='True')
df.display()

# %%
df = spark.read.option("quote","'").csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_pipe_single_quote.csv",header='True',sep='|',inferSchema='True')
df.display()

# %%
df = spark.read.csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_pipe_single_quote_escape.csv",header='True',sep='|',quote="'",inferSchema='True')
df.display()

# %%
df = spark.read.option("escape","#").option("quote","'").csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_pipe_single_quote_escape.csv",header='True',sep='|',quote="'",inferSchema='True')
df.display()

# %%
df = spark.read.option("escape","#").option("quote","'").csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_pipe_single_quote_escape_multiline.csv",header='True',sep='|',quote="'",inferSchema='True')
df.display()

# %%
df = spark.read.option("escape","#").option("quote","'").csv("/Volumes/spark_test_db/spark_csv_files/SparkCSV_Files_DifferentScenario/CSV Files/sales_pipe_single_quote_escape_multiline.csv",header='True',sep='|',quote="'",inferSchema='True',multiLine='True')
df.display()
