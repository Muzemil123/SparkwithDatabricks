# %%
df = spark.read.json("/Volumes/spark_test_db/spark_files/spark_json_files/JSON Files/sales_single_line.json")

# %%
df.write.format("parquet").save("/Volumes/spark_test_db/spark_files/spark_json_files/Parquetfile")

# %%
df2=spark.read.parquet("/Volumes/spark_test_db/spark_files/spark_json_files/Parquetfile")

# %%
df2.display()
