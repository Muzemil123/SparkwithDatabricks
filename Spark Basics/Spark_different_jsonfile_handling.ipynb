# %%
df = spark.read.json("/Volumes/spark_test_db/spark_files/spark_json_files/JSON Files/sales_single_line.json")
display(df)

# %%
df = spark.read.option("multiline", "true").json("/Volumes/spark_test_db/spark_files/spark_json_files/JSON Files/sales_multi_line.json").display()

# %%
df = spark.read.option("multiline", "true").json("/Volumes/spark_test_db/spark_files/spark_json_files/JSON Files/sales_multi_line.json")
df.write.format("json").save("/Volumes/spark_test_db/spark_files/spark_json_files/JSON Files/JSON write/sales_multi_lines.json")
